# %%
x=list(input())
# Out:
# chokuou

# %%
s=x
while(1):
    try:
        x.pop(x.index('o'))
    except:
        try:
            x.pop(x.index('k'))
        except:
            try:
                x.pop(x.index('u'))
            except:
                print('YES' if len(s) == 2*x.count('ch') else 'NO')
                break
            break
        break
    break
# Out:
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# ...

# %%
x
# Out:
# ['c', 'k', 'u', 'u']

# %%
x.pop(x.index('a'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-ef887a5065da> in <module>()
# ----> 1 x.pop(x.index('a'))
#
# ValueError: 'a' is not in list

# %%
s='chchch'
print('YES' if len(s) == 2*s.count('ch') else 'NO')
# Out:
# YES
