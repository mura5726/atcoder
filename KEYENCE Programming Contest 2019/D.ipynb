# %%
n,m=map(int,input().split())
a=list(map(int,input().split()))
b=list(map(int,input().split()))
# Out:
# 2 2
# 4 3
# 3 4

# %%
a
# Out:
# [4, 3]

# %%
def re_factorial(n):
    if n < 2:
        return 1
    return n * re_factorial(n-1)

# %%
for i in range(14*13):
    print(re_factorial(i) % (10**9 + 7))
# Out:
# 1
# 1
# 2
# 6
# 24
# 120
# 720
# 5040
# 40320
# 362880
# 3628800
# 39916800
# 479001600
# 227020758
# 178290591
# 674358851
# 789741546
# 425606191
# 660911389
# 557316307
# 146326063
# 72847302
# 602640637
# 860734560
# 657629300
# 440732388
# 459042011
# 394134213
# 35757887
# 36978716
# 109361473
# 390205642
# 486580460
# 57155068
# 943272305
# 14530444
# 523095984
# 354551275
# 472948359
# 444985875
# 799434881
# 776829897
# 626855450
# 954784168
# 10503098
# 472639410
# 741412713
# 846397273
# 627068824
# 726372166
# 318608048
# 249010336
# 948537388
# 272481214
# 713985458
# 269199917
# 75195247
# 286129051
# 595484846
# 133605669
# 16340084
# 996745124
# 798197261
# 286427093
# 331333826
# 536698543
# 422103593
# 280940535
# 103956247
# 172980994
# 108669496
# 715534167
# 518459667
# 847555432
# 719101534
# 932614679
# 878715114
# 661063309
# 562937745
# 472081547
# 766523501
# 88403147
# 249058005
# 671814275
# 432398708
# 753889928
# 834533360
# 604401816
# 187359437
# ...

# %%
14*13
# Out:
# 182
